# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
type(df['last_four'])
# Out:
# pandas.core.series.Series

# %%
df.rename(columns={'sex':'Gender'},inplace=True)

# %%
df.head()
# Out:
#    total_bill   tip  Gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
df['total_bill'].sum()
# Out:
# 4827.77

# %%
def yess(price):
    if price < 10:
        return 'Cheap'
    elif price >= 10 and price < 30:
        return 'Moderate'
    else:
        return 'Very Expensive'

# %%
#pd.set_option('display.float_format','{:,}'.format)

# %%
df['Nature_Bill'] = df['total_bill'].apply(yess)

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID last_four     Nature_Bill
# 234    Tracy Douglas  4097938155941930    Sat7220      1930        Moderate
# 235    Sean Gonzalez  3534021246117605    Sat4615      7605        Moderate
# 236    Matthew Myers  3543676378973965    Sat5032      3965        Moderate
# 237     Thomas Brown  4284722681265508    Sat2929      5508  Very Expensive
# 238   Kimberly Crane      676184013727    Sat9777      3727  Very Expensive
# 239    Michael Avila  5296068606052842    Sat2657      2842        Moderate
# 240   Monica Sanders  3506806155565404    Sat1766      5404        Moderate
# 241       Keith Wong  6011891618747196    Sat3880      7196        Moderate
# 242     Dennis Dixon     4375220550950      Sat17      0950        Moderate
# 243  Michelle Hardin  3511451626698139    Thur672      8139        Moderate

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
simple(12)
# Out:
# 24

# %%
f=lambda num: num*2

# %%
print(f(10))
# Out:
# 20

# %%
x=lambda a,b:a+b

# %%
print(x(23,78))
# Out:
# 101

# %%
y=lambda a,b: a if a>b else b

# %%
print(y(1,6))
# Out:
# 6

# %%
print(y(10,5))
# Out:
# 10

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate

# %%
df["GST"]=df['total_bill'].apply(lambda total_bill:total_bill*0.18)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST
# 0  3.0582
# 1  1.8612
# 2  3.7818
# 3  4.2624
# 4  4.4262

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST
# 0  3.0582
# 1  1.8612
# 2  3.7818
# 3  4.2624
# 4  4.4262

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df['Tip_Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality
# 0  3.0582       Other
# 1  1.8612       Other
# 2  3.7818       Other
# 3  4.2624       Other
# 4  4.4262       Other

# %%
len(df[df['Tip_Quality']=='Generous'])
# Out:
# 10

# %%
import numpy as np

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
#df['test']=np.vectorize(yess)(df['total_bill'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other       Other
# 1  1.8612       Other       Other
# 2  3.7818       Other       Other
# 3  4.2624       Other       Other
# 4  4.4262       Other       Other

# %%
def myfunc(a, b):
    if a > b:
        return a - b
    else:
        return a + b

vfunc = np.vectorize(myfunc)
vfunc([1, 2, 3, 4], 2)
# Out:
# array([3, 4, 1, 2])

# %% [markdown]
# So, which one is faster?

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 8.85743261200001

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.3872150939999983

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number  \
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15
#
#               GST
# count  244.000000
# mean     3.561470
# std      1.602434
# min      0.552600
# 25%      2.402550
# 50%      3.203100
# 75%      4.342950
# max      9.145800

# %% [markdown]
# #univariate analysis
# #total_bill=average total_bill is 19.7, median is 17, hence it is right skewed distribution, range is 50-3=47
# tip=average tip 3, median 3,

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
# GST               244.0  3.561470e+00  1.602434e+00  5.526000e-01
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15
# GST               2.402550e+00  3.203100e+00  4.342950e+00  9.145800e+00

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267
# 236       Matthew Myers  3543676378973965    Sat5032      3965
# 92         Leah Ramirez  3508911676966392    Fri3780      6392
# 111         Terri Jones  3559221007826887    Sat4801      6887
# 0    Christy Cunningham  3560325168603410    Sun2959      3410
# ..                  ...               ...        ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508
# 59          Brian Ortiz  6596453823950595    Sat8139      0595
# 23       Lance Peterson  3542584061609808     Sat239      9808
# 212     Alex Williamson      676218815212    Sat4590      5212
# 170       Gregory Clark  5473850968388236    Sat1954      8236
#
#         Nature_Bill     GST Tip_Quality Tip Quality
# 67            Cheap  0.5526    Generous    Generous
# 236        Moderate  2.2680       Other       Other
# 92            Cheap  1.0350       Other       Other
# 111           Cheap  1.3050       Other       Other
# 0          Moderate  3.0582       Other       Other
# ..              ...     ...         ...         ...
# 141  Very Expensive  6.1740       Other       Other
# 59   Very Expensive  8.6886       Other       Other
# 23   Very Expensive  7.0956       Other       Other
# 212  Very Expensive  8.6994       Other       Other
# 170  Very Expensive  9.1458       Other       Other
#
# [244 rows x 16 columns]

# %%
#find first 5 customers whose total_bill is highest
df.sort_values('total_bill',ascending=False).head()
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 182     Jose Parsons  4112207559459910    Sun2337

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','total_bill'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959
# ..                  ...               ...        ...
# 141      Steven Carlson  3526515703718508   Thur1025
# 59          Brian Ortiz  6596453823950595    Sat8139
# 23       Lance Peterson  3542584061609808     Sat239
# 212     Alex Williamson      676218815212    Sat4590
# 170       Gregory Clark  5473850968388236    Sat1954
#
# [244 rows x 11 columns]

# %% [markdown]
# # Exercise
# #sort values for total_bill and price_per_person

# %%
#selecting tip more than 5.0

df[df['tip']>5.0]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2             11.66
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4              6.47
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
#
#             Payer Name         CC Number Payment ID
# 23      Lance Peterson  3542584061609808     Sat239
# 44         Todd Cooper      503846761263    Sun2274
# 47        James Barnes  3552002592874186    Sun9677
# 52        Emily Daniel  4291280793094374    Sun6165
# 59         Brian Ortiz  6596453823950595    Sat8139
# 85         Shawna Cook  6011787464177340   Thur7972
# 88        Roger Taylor     4410248629955   Thur9003
# 116        Shawn Blake  4689079711213722      Sun22
# 141     Steven Carlson  3526515703718508   Thur1025
# 155     Madison Wilson  4210875236164664    Sun9176
# 170      Gregory Clark  5473850968388236    Sat1954
# 172        Larry White    30432617123103    Sun9209
# 181          Jason Cox  6556931703586223    Sun3402
# 183  Dr. Michael James     4718501859162    Sun6059
# 211     Christopher Li  6011962464150569    Sat6735
# 212    Alex Williamson      676218815212    Sat4590
# 214    Marissa Jackson  4922302538691962    Sat3374
# 239      Michael Avila  5296068606052842    Sat2657

# %%
#finding only Sat and Sun
df.loc[df['day'].isin(['Sat','Sun'])]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID last_four  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410
# 1        Douglas Tucker  4478071379779230    Sun4608      9230
# 2        Travis Walters  6011812112971322    Sun4458      1322
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994
# 4          Tonya Carter  4832732618637221    Sun2251      7221
# ..                  ...               ...        ...       ...
# 238      Kimberly Crane      676184013727    Sat9777      3727
# 239       Michael Avila  5296068606052842    Sat2657      2842
# 240      Monica Sanders  3506806155565404    Sat1766      5404
# 241          Keith Wong  6011891618747196    Sat3880      7196
# 242        Dennis Dixon     4375220550950      Sat17      0950
#
#         Nature_Bill     GST Tip_Quality Tip Quality
# 0          Moderate  3.0582       Other       Other
# 1          Moderate  1.8612       Other       Other
# 2          Moderate  3.7818       Other       Other
# 3          Moderate  4.2624       Other       Other
# 4          Moderate  4.4262       Other       Other
# ..              ...     ...         ...         ...
# 238  Very Expensive  6.4494       Other       Other
# 239        Moderate  5.2254       Other       Other
# 240        Moderate  4.8924       Other       Other
# 241        Moderate  4.0806       Other       Other
# 242        Moderate  3.2076       Other       Other
#
# [163 rows x 16 columns]

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number  \
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000
# GST                 1.000000  0.675734  0.598315          0.647554   0.104576
#
#                        GST
# total_bill        1.000000
# tip               0.675734
# size              0.598315
# price_per_person  0.647554
# CC Number         0.104576
# GST               1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other       Other
# 1  1.8612       Other       Other
# 2  3.7818       Other       Other
# 3  4.2624       Other       Other
# 4  4.4262       Other       Other

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                               10
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Nature_Bill           Very Expensive
# GST                           9.1458
# Tip_Quality                    Other
# Tip Quality                    Other
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                                1
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_four                       5267
# Nature_Bill                    Cheap
# GST                           0.5526
# Tip_Quality                 Generous
# Tip Quality                 Generous
# Name: 67, dtype: object

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                               10
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Nature_Bill           Very Expensive
# GST                           9.1458
# Tip_Quality                    Other
# Tip Quality                    Other
# Name: 170, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other       Other
# 1  1.8612       Other       Other
# 2  3.7818       Other       Other
# 3  4.2624       Other       Other
# 4  4.4262       Other       Other

# %%
df['sex'].value_counts()#CATEGORICAL VARIABLE
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
#Exercise
#find value counts of smoking,day and time
#find % of smokers

# %%
a=len(df[df['sex']=='Male'])/244*100
print("Male Percentage:", a)
b=100-a
print("Female percentage:",b)
# Out:
# Male Percentage: 64.34426229508196
# Female percentage: 35.65573770491804

# %%
#how many customers are male smoker
len(df[(df['smoker'] == 'Yes') & (df['sex']=='Male')])
# Out:
# 60

# %%
#how many customers are female smoker
len(df[(df['smoker'] == 'Yes') & (df['sex']!='Male')])
# Out:
# 33

# %%
#how many customers are smokers
c=len(df[df['smoker']=='Yes'])/244*100
print('smoker percentage:',round(c,3),'%')
# Out:
# smoker percentage: 38.115 %

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other       Other
# 1  1.8612       Other       Other
# 2  3.7818       Other       Other
# 3  4.2624       Other       Other
# 4  4.4262       Other       Other

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# 0      Ok
# 1      Ok
# 2      Ok
# 3      Ok
# 4      Ok
#        ..
# 239    Ok
# 240    Ok
# 241    Ok
# 242    Ok
# 243    Ok
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other          Ok
# 1  1.8612       Other          Ok
# 2  3.7818       Other          Ok
# 3  4.2624       Other          Ok
# 4  4.4262       Other          Ok

# %% [markdown]
# <a id='uni'></a>
# ### unique :

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df['size'].nunique()#count of distinct obs.
# Out:
# 6

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['size'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object

# %%
#making full form of days. 
#In replace method, we only replaced one value, however map is used for multiple values

m={'Sun':'Sunday','Sat':'Saturday','Fri':'Friday'}
df['day'].map(m)
# Out:
# 0        Sunday
# 1        Sunday
# 2        Sunday
# 3        Sunday
# 4        Sunday
#          ...
# 239    Saturday
# 240    Saturday
# 241    Saturday
# 242    Saturday
# 243         NaN
# Name: day, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1      Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2      Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4        Tonya Carter  4832732618637221    Sun2251      7221    Moderate
#
#       GST Tip_Quality Tip Quality
# 0  3.0582       Other          Ok
# 1  1.8612       Other          Ok
# 2  3.7818       Other          Ok
# 3  4.2624       Other          Ok
# 4  4.4262       Other          Ok

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, price_per_person, Payer Name, CC Number, Payment ID]
# Index: []

# %%
simple_df = pd.DataFrame(data=[1,2,2],index=['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary
# right: A scalar value that defines the right boundary
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %%
df['total_bill'].between(10,20,inclusive=True)
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1        Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 8       Joseph Mcdonald  3522866365840377    Sun6820      0377    Moderate
# 9         Jerome Abbott  3532124519049786    Sun3775      9786    Moderate
# 10        William Riley      566287581219    Sun2546      1219    Moderate
# ..                  ...               ...        ...       ...         ...
# 234       Tracy Douglas  4097938155941930    Sat7220      1930    Moderate
# 235       Sean Gonzalez  3534021246117605    Sat4615      7605    Moderate
# 236       Matthew Myers  3543676378973965    Sat5032      3965    Moderate
# 242        Dennis Dixon     4375220550950      Sat17      0950    Moderate
# 243     Michelle Hardin  3511451626698139    Thur672      8139    Moderate
#
#         GST Tip_Quality Tip Quality
# 0    3.0582       Other          Ok
# 1    1.8612       Other          Ok
# 8    2.7072       Other          Ok
# 9    2.6604       Other          Ok
# 10   1.8486       Other          Ok
# ..      ...         ...         ...
# 234  2.7954       Other          Ok
# 235  1.8126       Other          Ok
# 236  2.2680       Other          Ok
# 242  3.2076       Other          Ok
# 243  3.3804       Other          Ok
#
# [130 rows x 16 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4              8.66
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 140       17.47  3.50  Female     No  Thur   Lunch     2              8.74
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2              8.94
#
#            Payer Name         CC Number Payment ID last_four     Nature_Bill  \
# 180  James Hebert DDS      676168737648    Sun7544      7648  Very Expensive
# 2      Travis Walters  6011812112971322    Sun4458      1322        Moderate
# 26         Kyle Avery  6531339539615499    Sat6651      5499        Moderate
# 140        Kayla Rios  5233918213804470   Thur3906      4470        Moderate
# 176    Walter Simmons  6011481578696110    Sun5961      6110        Moderate
#
#         GST Tip_Quality Tip Quality
# 180  6.2370       Other          Ok
# 2    3.7818       Other          Ok
# 26   2.4066       Other          Ok
# 140  3.1446       Other          Ok
# 176  3.2202       Other          Ok

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 17        16.29  3.71    Male     No   Sun  Dinner     3              5.43
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2              5.80
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2              6.08
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 136       10.33  2.00  Female     No  Thur   Lunch     2              5.16
# 57        26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4              7.54
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 129       22.82  2.18    Male     No  Thur   Lunch     3              7.61
# 31        18.35  2.50    Male     No   Sat  Dinner     4              4.59
# 150       14.07  2.50    Male     No   Sun  Dinner     2              7.04
# 54        25.56  4.34    Male     No   Sun  Dinner     4              6.39
# 212       48.33  9.00    Male     No   Sat  Dinner     4             12.08
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2             15.92
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 185       20.69  5.00    Male     No   Sun  Dinner     5              4.14
# 132       11.17  1.50  Female     No  Thur   Lunch     2              5.58
# 70        12.02  1.97    Male     No   Sat  Dinner     2              6.01
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3              8.86
# 113       23.95  2.55    Male     No   Sun  Dinner     2             11.98
#
#             Payer Name         CC Number Payment ID last_four     Nature_Bill  \
# 17        John Pittman  6521340257218708    Sun2998      8708        Moderate
# 3     Nathaniel Harris  4676137647685994    Sun5260      5994        Moderate
# 217           Gary Orr    30324521283406    Sat8489      3406        Moderate
# 220      Ricky Johnson   213109508670736    Fri4607      0736        Moderate
# 216  Shawn Barnett PhD     4590982568244    Sat7320      8244        Moderate
# 230    Michael Osborne     4258682154026    Sat7872      4026        Moderate
# 136        Donna Kelly   180048553626376   Thur1393      6376        Moderate
# 57        Melody Simon  4745394421258160    Sat8980      8160        Moderate
# 241         Keith Wong  6011891618747196    Sat3880      7196        Moderate
# 205        Carly Reyes     4787787236486   Thur8084      6486        Moderate
# 219       Shelby House      502097403252    Sat8863      3252  Very Expensive
# 225     Whitney Arnold  3579111947217428    Fri6665      7428        Moderate
# 129     Raymond Torres     4855776744024   Thur9424      4024        Moderate
# 31      Danny Santiago      630415546013    Sat4947      6013        Moderate
# 150          Luke Rice  4813617017359506    Sun8863      9506        Moderate
# 54        Ronald Owens  6569607991983380    Sun9470      3380        Moderate
# 212    Alex Williamson      676218815212    Sat4590      5212  Very Expensive
# 173        Scott Perez  3577115550328507    Sun9335      8507  Very Expensive
# 85         Shawna Cook  6011787464177340   Thur7972      7340  Very Expensive
# 185      Joseph Howell    30362407455623    Sun5842      5623        Moderate
# 132    Taylor Gonzalez  6011990685390011   Thur7783      0011        Moderate
# 70           Max Brown   213139760497718    Sat2100      7718        Moderate
# 206       Daniel Owens    38971087967574       Sat1      7574        Moderate
# 113         John Joyce  6565964211060570    Sun1885      0570        Moderate
#
#         GST Tip_Quality Tip Quality
# 17   2.9322       Other          Ok
# 3    4.2624       Other          Ok
# 217  2.0862       Other          Ok
# 220  2.1888       Other          Ok
# 216  5.0670       Other          Ok
# 230  4.3218       Other          Ok
# 136  1.8594       Other          Ok
# 57   4.7538       Other          Ok
# 241  4.0806       Other          Ok
# 205  2.9646       Other          Ok
# 219  5.4252       Other          Ok
# 225  2.9286       Other          Ok
# 129  4.1076       Other          Ok
# 31   3.3030       Other          Ok
# 150  2.5326       Other          Ok
# 54   4.6008       Other          Ok
# 212  8.6994       Other          Ok
# 173  5.7330       Other          Ok
# 85   6.2694       Other          Ok
# 185  3.7242       Other          Ok
# 132  2.0106       Other          Ok
# 70   2.1636       Other          Ok
# 206  4.7862       Other          Ok
# 113  4.3110       Other          Ok

# %%
df1=df.copy()
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410    Moderate
# 1        Douglas Tucker  4478071379779230    Sun4608      9230    Moderate
# 2        Travis Walters  6011812112971322    Sun4458      1322    Moderate
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994    Moderate
# 4          Tonya Carter  4832732618637221    Sun2251      7221    Moderate
# ..                  ...               ...        ...       ...         ...
# 239       Michael Avila  5296068606052842    Sat2657      2842    Moderate
# 240      Monica Sanders  3506806155565404    Sat1766      5404    Moderate
# 241          Keith Wong  6011891618747196    Sat3880      7196    Moderate
# 242        Dennis Dixon     4375220550950      Sat17      0950    Moderate
# 243     Michelle Hardin  3511451626698139    Thur672      8139    Moderate
#
#         GST Tip_Quality Tip Quality
# 0    3.0582       Other          Ok
# 1    1.8612       Other          Ok
# 2    3.7818       Other          Ok
# 3    4.2624       Other          Ok
# 4    4.4262       Other          Ok
# ..      ...         ...         ...
# 239  5.2254       Other          Ok
# 240  4.8924       Other          Ok
# 241  4.0806       Other          Ok
# 242  3.2076       Other          Ok
# 243  3.3804       Other          Ok
#
# [244 rows x 16 columns]

# %%
df1.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number  \
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15
#
#               GST
# count  244.000000
# mean     3.561470
# std      1.602434
# min      0.552600
# 25%      2.402550
# 50%      3.203100
# 75%      4.342950
# max      9.145800

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID last_four     Nature_Bill  \
# 170      Gregory Clark  5473850968388236    Sat1954      8236  Very Expensive
# 212    Alex Williamson      676218815212    Sat4590      5212  Very Expensive
# 23      Lance Peterson  3542584061609808     Sat239      9808  Very Expensive
# 59         Brian Ortiz  6596453823950595    Sat8139      0595  Very Expensive
# 141     Steven Carlson  3526515703718508   Thur1025      8508  Very Expensive
# 183  Dr. Michael James     4718501859162    Sun6059      9162        Moderate
# 214    Marissa Jackson  4922302538691962    Sat3374      1962        Moderate
# 47        James Barnes  3552002592874186    Sun9677      4186  Very Expensive
# 239      Michael Avila  5296068606052842    Sat2657      2842        Moderate
# 88        Roger Taylor     4410248629955   Thur9003      9955        Moderate
#
#         GST Tip_Quality Tip Quality
# 170  9.1458       Other          Ok
# 212  8.6994       Other          Ok
# 23   7.0956       Other          Ok
# 59   8.6886       Other          Ok
# 141  6.1740       Other          Ok
# 183  4.1706    Generous    Generous
# 214  5.0706       Other          Ok
# 47   5.8320       Other          Ok
# 239  5.2254       Other          Ok
# 88   4.4478       Other          Ok

# %%
df.nsmallest(5,'total_bill')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
#
#          Payer Name         CC Number Payment ID last_four Nature_Bill  \
# 67    Tiffany Brock  4359488526995267    Sat3455      5267       Cheap
# 92     Leah Ramirez  3508911676966392    Fri3780      6392       Cheap
# 111     Terri Jones  3559221007826887    Sat4801      6887       Cheap
# 172     Larry White    30432617123103    Sun9209      3103       Cheap
# 149  Daniel Robbins  4823139288341889   Thur6321      1889       Cheap
#
#         GST Tip_Quality Tip Quality
# 67   0.5526    Generous    Generous
# 92   1.0350       Other          Ok
# 111  1.3050       Other          Ok
# 172  1.3050    Generous    Generous
# 149  1.3518    Generous    Generous

# %% [markdown]
# ----

# %%
#creating dataframe from dictionary
Yess_Class = pd.DataFrame({'Student ID':[111, 222, 333, 444], 
                               'Name':['Kiran', 'Prasad', 'Suvarna', 'Snehal'], 
                               'Age':[23, 22, 20, 26], 
                               'Education':['BE', 'MSc', 'BTech', 'BSc']})
Yess_Class
# Out:
#    Student ID     Name  Age Education
# 0         111    Kiran   23        BE
# 1         222   Prasad   22       MSc
# 2         333  Suvarna   20     BTech
# 3         444   Snehal   26       BSc
